# %% [markdown]
# This notebook explores how to check text similarity among two list of texts.

# %%
import math
# Load eb kg dataframe
import pandas as pd
eb_kg_df = pd.read_json("../eb_kg_hq_with_embeddings_dataframe", orient="index")

# %% [markdown]
# Using sklearn library

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

model = SentenceTransformer('all-mpnet-base-v2')
def calculating_similarity_sklearn(query_embedding, text_embeddings, top_n=20, offset=0):
    similarities=cosine_similarity( [query_embedding], text_embeddings)
    similarities_sorted = similarities.argsort()
    result = []
    start = -1 - offset
    end = start - top_n
    for index in similarities_sorted[0][start:end:-1]:
        result.append({
            "index": index,
            "score": similarities[0][index]
        })
    return result

# %%
text_embeddings = eb_kg_df["embedding"].values.tolist()

# %%
query_embedding = text_embeddings[0]

# %%
query_embedding
# Out:
# [0.0667808577,
#  -0.1191483587,
#  0.0258066095,
#  -0.0154051194,
#  0.0177952293,
#  0.005992443300000001,
#  0.0086399661,
#  0.0618461259,
#  -0.0033398916,
#  0.005896432300000001,
#  0.014627636400000001,
#  0.0438207388,
#  0.0130106201,
#  -0.08083358410000001,
#  0.0270166956,
#  -0.0680485591,
#  -0.0445473716,
#  0.0502884388,
#  0.029745051600000003,
#  0.002854231,
#  -0.0256614294,
#  0.038261733900000004,
#  -0.010777960500000001,
#  0.0328972042,
#  -0.0182807855,
#  -0.0265123285,
#  0.0293891933,
#  0.028690232000000003,
#  -0.063238658,
#  -0.0045688478,
#  -0.0137779284,
#  -0.0777471587,
#  -0.0070252493000000004,
#  -0.0108974073,
#  1.9242e-06,
#  -0.0074232947,
#  0.0314941928,
#  0.0012543703,
#  0.0154032484,
#  -0.0287385751,
#  0.014461278000000001,
#  -0.0274059866,
#  0.0502606928,
#  -0.005175781,
#  0.007666277700000001,
#  -7.57975e-05,
#  -0.0391709097,
#  -0.0277074073,
#  -0.0332484059,
#  0.0609931946,
#  -0.0010288119,
#  -0.0453827381,
#  -0.0085687572,
#  -0.0302264057,
#  0.022930976000000002,
#  -0.0363037474,
#  0.0101896971,
#  0.0089511834,
#  -0.0259510465,
#  -0.07104399800000001,
#  -0.020663000600000002,
#  -0.0324594714,
#  -0.0247313417,
#  0.0542747118,
#  -0.0785998031,
#  -0.0332506783,
#  -0.024695972,
#  0.0351391807,
#  -0.019570404700000002,
#  -0.030010582900000003,
#  0.0319997221,
#  0.0008837683,
#  0.0161892008,
#  0.028865078500000002,
#  0.0270527545,
#  -0.0435144939,
#  -0.010846596200000001,
#  -0.0245071631,
#  -0.0082079628,
#  -0.0028035892,
#  0.0340164341,
#  0.0258129463,
#  -0.05258568,
#  0.0037122911,
#  -0.0227348637,
#  0.015830757100000002,
#  -0.0090150833,
#  0.019323688000000002,
#  0.0535256304,
#  -0.0462260917,
#  -0.0031999641,
#  0.0506596863,
#  0.0384206511,
#  0.027578011200000002,
#  0.053090401,
#  -0.0132150957,
#  0.0025774161,
#  -0.043494507700000004,
#  0.0174995046,
#  -0.07812458280000001,
#  -0.0335900337,
#  -0.054766703400000005,
#  -0.0190589167,
#  0.0512336381,
#  -0.012068867700000001,
#  -0.0576663986,
#  0.0995723382,
#  -0.0244570915,
#  -0.0025043027,
#  -0.0103255399,
#  0.0393163636,
#  0.0221079644,
#  0.0108541474,
#  -0.0031527432,
#  0.0420829505,
#  -0.0135663077,
#  -0.0184835754,
#  -0.0135737779,
#  0.0014575933,
#  -0.003080708,
#  -0.0497526936,
#  -0.0163266305,
#  -0.0057194359,
#  -0.0223786831,
#  0.0510231219,
#  0.0037639590000000003,
#  -0.0218710098,
#  0.0690443292,
#  -0.00674862,
#  -0.031821765,
#  0.0245665405,
#  0.0088573806,
#  -0.0011444646,
#  -0.054343044800000004,
#  0.0418742895,
#  0.0509890765,
#  0.0713199377,
#  -0.0114194984,
#  0.027840796900000003,
#  0.058324113500000004,
#  0.0170493741,
#  -0.033911939700000004,
#  -0.0358959436,
#  0.061784122100000005,
#  -0.0190968905,
#  0.014479175200000001,
#  0.0031038234,
#  -0.07235851880000001,
#  -0.0069226581,
#  -0.0196494758,
#  -0.0355683677,
#  -0.0658491254,
#  0.0555840842,
#  0.036546118600000004,
#  -0.032082017500000004,
#  0.0186976492,
#  -0.042390909000000004,
#  -0.0167332795,
#  -0.0430618227,
#  -0.010195594300000001,
#  0.0213974528,
#  0.022967940200000002,
#  0.026080261900000002,
#  0.011032504,
#  -0.030667960600000002,
#  0.0402539484,
#  -0.07313948120000001,
#  0.021856254000000002,
#  -0.0204766244,
#  -0.047728326200000004,
#  0.0090612993,
#  -0.0012183627,
#  0.010902636700000001,
#  0.0734454542,
#  -0.0099808015,
#  0.0180654489,
#  -0.0485903695,
#  0.0722766593,
#  -0.0476331823,
#  0.0171045847,
#  0.0403021947,
#  -0.034015409600000004,
#  0.0149139361,
#  -0.0017051449,
#  0.06722007690000001,
#  -0.0013317351,
#  0.11638113110000001,
#  0.0216814801,
#  -0.0024560459,
#  0.0480719693,
#  0.0038699622000000003,
#  -0.0220918916,
#  -0.0090634255,
#  0.00036698110000000004,
#  -0.014128442900000001,
#  -0.0381004475,
#  0.0117192222,
#  0.0261123553,
#  -0.0057975487,
#  -0.0065440284000000005,
#  -0.0280371159,
#  -0.021537127,
#  -0.0031762347000000002,
#  -0.0051395618,
#  -0.0063061556,
#  0.0124128601,
#  0.0421446189,
#  0.012889652500000001,
#  -0.0229640771,
#  -0.0290339552,
#  -0.0934822336,
#  0.0396969058,
#  -0.0100381114,
#  0.0185170323,
#  0.021352442000000003,
#  0.0191847272,
#  0.0039044472,
#  0.0275871195,
#  -0.10411568730000001,
#  0.0801981613,
#  0.0094705028,
#  0.0208824165,
#  -0.0229186881,
#  -0.0537142381,
#  -0.0011634472,
#  -0.026867197800000003,
#  -0.015653779700000002,
#  -0.0117755337,
#  -0.007442459,
#  -0.015733875300000002,
#  0.0114770783,
#  0.0105181728,
#  -0.0169794466,
#  0.001646972,
#  0.0441068374,
#  0.018903205200000002,
#  -0.0200831071,
#  0.0228006151,
#  0.0094273249,
#  -0.0679600984,
#  0.0385147743,
#  0.042031128,
#  -0.0167595614,
#  -0.0527979247,
#  0.030210988600000002,
#  -0.0407614149,
#  0.0132581033,
#  -0.0097967135,
#  -0.0078105433,
#  -0.0748312399,
#  -0.015474572800000001,
#  0.0604612678,
#  -0.0642230585,
#  -0.0074538663000000005,
#  0.0012862042,
#  -0.0165592004,
#  -0.0349356383,
#  0.0069855014,
#  0.0061333515,
#  -0.0791674405,
#  -0.0052131815000000005,
#  -0.0156786684,
#  -0.0603986867,
#  -0.034098655000000005,
#  0.0289924573,
#  0.0116739701,
#  0.012599014700000001,
#  -0.0557355545,
#  0.0598445237,
#  -0.0038541406,
#  -0.0066765286,
#  -0.0080296751,
#  -0.023671653100000002,
#  -0.07583994420000001,
#  -0.0170792621,
#  -0.009751403700000001,
#  -0.0013386210000000001,
#  -0.0131618772,
#  -0.0052959989,
#  -0.0247095227,
#  0.0301749371,
#  -0.018236516,
#  -0.0076080132,
#  0.0074684592,
#  -0.027774870400000002,
#  -0.0262830872,
#  -0.0146441022,
#  0.0492013805,
#  0.0482087098,
#  0.0587361194,
#  -0.0648514703,
#  -0.017785985,
#  0.0138261262,
#  -0.0047708694,
#  -0.0019036457,
#  0.0152222672,
#  0.076001808,
#  0.0093019893,
#  0.0091280499,
#  -0.0209470876,
#  -0.0023007076,
#  -0.0398882292,
#  0.0756357387,
#  0.0201095119,
#  -0.1094764397,
#  -0.0011098953,
#  -0.0118732657,
#  -0.0583539531,
#  -0.045730050700000004,
#  0.00041157110000000004,
#  0.0095390063,
#  -0.031006127600000002,
#  -0.0112539437,
#  0.0579210818,
#  0.0122282794,
#  0.0580038838,
#  0.0172353163,
#  0.0043316707,
#  -0.030903548000000003,
#  -0.0400426313,
#  0.000277289,
#  -0.0143723637,
#  -0.0135395909,
#  0.0278493874,
#  0.025269415200000003,
#  -0.0311867334,
#  0.0145269101,
#  -0.027065115,
#  0.0678200424,
#  -0.010947885000000001,
#  -0.0296688136,
#  -0.0195712987,
#  0.054466165600000005,
#  -0.0107140811,
#  0.040682371700000004,
#  0.0168641824,
#  -0.0614636987,
#  -0.0368088037,
#  0.0261710063,
#  -0.0146932593,
#  -0.0186983179,
#  0.045257128800000004,
#  0.0790727884,
#  0.049780484300000004,
#  -0.057655520700000004,
#  -0.028118116800000002,
#  -0.0019503454000000002,
#  0.0169913452,
#  0.0064794836000000005,
#  -0.050247423400000005,
#  -0.0344874971,
#  -0.0173829477,
#  -0.0063038003000000006,
#  -0.0067520137,
#  -0.0032506108,
#  -0.0616719425,
#  0.0083349161,
#  -0.015141739500000001,
#  0.0427333936,
#  0.0441144258,
#  0.0219974201,
#  -0.0203964952,
#  0.0142340511,
#  -0.0610330179,
#  0.0432495587,
#  -0.0441542268,
#  0.0084105637,
#  0.0474256054,
#  -0.0085847322,
#  0.013610834300000001,
#  -0.058952886600000004,
#  -0.0002653077,
#  0.008558796700000001,
#  -0.0172911678,
#  -0.0402583964,
#  0.0003398705,
#  -0.0013586014,
#  -0.0444223471,
#  0.0991705209,
#  0.0817658976,
#  -0.0185433719,
#  0.0234814286,
#  -0.0547566824,
#  0.0007133425,
#  0.0328440107,
#  0.0385589376,
#  0.0549599081,
#  0.0121146226,
#  -0.0013032507,
#  -0.035587199,
#  -0.0189336296,
#  -0.0147702675,
#  0.051986496900000005,
#  0.020228903700000002,
#  -0.0023152281,
#  0.0007870249000000001,
#  -0.009355001200000001,
#  -0.0103104096,
#  -0.0041686194,
#  0.0189634934,
#  0.0601312481,
#  -0.025932043800000002,
#  -0.0049084267,
#  -0.024761227900000002,
#  0.030242545500000002,
#  0.0503250062,
#  -0.0171959046,
#  0.06380581860000001,
#  -0.0253254119,
#  0.0246358607,
#  -0.0504803136,
#  -0.0318424441,
#  -0.0047110682,
#  0.0342799127,
#  -0.0141521925,
#  0.015199158300000001,
#  0.036260739,
#  -0.0032163183000000002,
#  -0.0689496621,
#  -0.0089754416,
#  0.0373180881,
#  -0.0129551478,
#  0.009301099,
#  -0.024742923700000002,
#  -0.0608631782,
#  -0.0022015462,
#  -0.015677915900000002,
#  0.0344458483,
#  0.037281394,
#  0.012404887000000002,
#  0.0252784044,
#  0.0006691091,
#  -0.020185051500000002,
#  0.0287720375,
#  -0.0124081047,
#  -0.0539752729,
#  -0.031245052800000003,
#  -0.0679180399,
#  0.011734209,
#  0.0177031755,
#  0.0024265395000000003,
#  -0.0197749957,
#  0.00457627,
#  -0.0027572617000000002,
#  -0.0111361351,
#  -0.0730825886,
#  -0.0049830629,
#  -0.042004797600000005,
#  0.0018129697,
#  0.0395778455,
#  -0.0328706093,
#  -0.0178068765,
#  -0.016032893200000002,
#  0.027851354300000002,
#  -0.0026592012,
#  -0.025974707700000002,
#  -0.0088856779,
#  -0.0123283025,
#  0.0226768684,
#  -0.0422427878,
#  0.06500255320000001,
#  0.011832072400000001,
#  0.019199242800000002,
#  0.027688022700000002,
#  0.0709822178,
#  0.0164248664,
#  -0.0185218956,
#  -0.0447970368,
#  0.0310377218,
#  0.0328456946,
#  -0.013709159600000001,
#  0.0110896034,
#  -0.0026402918,
#  -0.0097573856,
#  0.028016855900000002,
#  0.0654229298,
#  0.0156557206,
#  0.006491203300000001,
#  -0.013798989400000001,
#  0.0086134281,
#  -0.0166698359,
#  -0.0755253509,
#  -6.288930000000001e-05,
#  -0.08938932420000001,
#  0.012421959100000001,
#  -0.0130412932,
#  0.0209818874,
#  0.0158894639,
#  0.010710486200000001,
#  0.0224550255,
#  0.011698884000000001,
#  0.0126691684,
#  0.0091453129,
#  -0.0152914179,
#  0.0694525689,
#  -0.0509879887,
#  0.0035593503000000003,
#  -0.0130154015,
#  0.0922937691,
#  -0.0627939701,
#  -0.0156405009,
#  0.0290028378,
#  0.0345602632,
#  -0.0008832979,
#  -0.0502895229,
#  0.0308895148,
#  0.0040899785,
#  -0.0326966904,
#  0.0194929671,
#  -0.061073698100000004,
#  0.041118349900000004,
#  -0.020953424300000002,
#  -0.0466645434,
#  -0.0025508394,
#  0.0042318134,
#  -0.07987003770000001,
#  0.0072829681,
#  -0.0103075234,
#  0.0541377813,
#  -0.0175871048,
#  -0.005500792500000001,
#  -0.0344161168,
#  0.019677035500000002,
#  -0.029441030700000002,
#  0.0024661713,
#  -0.028824336800000003,
#  -0.0466358811,
#  0.0188404769,
#  0.0198329501,
#  -0.0299868621,
#  -0.0812588781,
#  0.0847355872,
#  0.0173356943,
#  0.0308559071,
#  0.0431689285,
#  0.009252945,
#  0.0950849354,
#  -0.0201556478,
#  0.0371282957,
#  0.0362477191,
#  -0.0131531693,
#  0.003241756,
#  0.0729000717,
#  -0.0172322746,
#  0.0321920849,
#  -0.044462006500000005,
#  0.0180113558,
#  0.0282229111,
#  0.0311205536,
#  0.0433166511,
#  -0.029749605800000002,
#  0.0715305582,
#  -0.0942292958,
#  0.0043889279,
#  0.011027755200000001,
#  -6.324730457e-33,
#  0.0294056162,
#  0.041343405800000003,
#  0.0102687217,
#  0.045632861600000005,
#  -0.0051112538,
#  0.0385971777,
#  0.0032560518,
#  0.021142073,
#  0.0020381834,
#  -0.0029056391000000003,
#  0.046263810200000005,
#  -0.0330118015,
#  0.00032109930000000003,
#  -0.0012064783,
#  0.0251291078,
#  0.039583452000000005,
#  -0.0670016035,
#  -0.0042179837000000005,
#  -0.0026991167,
#  -0.029043803000000003,
#  0.0817052051,
#  0.0005166130000000001,
#  0.0202988703,
#  0.0518255904,
#  0.043801389600000004,
#  0.012339209200000001,
#  -0.0380826741,
#  0.0027579090000000002,
#  0.0487255529,
#  -0.026996471,
#  -0.0009640786,
#  -0.0312386844,
#  0.0344991423,
#  0.0732342601,
#  0.0322863273,
#  -0.009152337,
#  0.0289166849,
#  -0.0040044193,
#  0.029101187400000002,
#  0.0424376242,
#  -0.02507619,
#  0.0503726192,
#  -0.034643445200000005,
#  0.0134244533,
#  -0.0287163034,
#  -0.016766393600000002,
#  -0.0346465372,
#  0.03380128,
#  -0.0273152143,
#  -0.1076343134,
#  0.0588091835,
#  0.0076443404000000005,
#  -0.0616620108,
#  -0.0789807141,
#  0.0171936769,
#  -0.0229088254,
#  0.009741094,
#  0.029484905300000003,
#  0.0182701107,
#  -0.0053504971000000005,
#  -0.041094269600000004,
#  -0.050624866000000004,
#  -0.0342387035,
#  -0.003977776000000001,
#  -0.0247088149,
#  0.0499237292,
#  0.0195327457,
#  -0.0369471237,
#  0.0005471571,
#  0.0343936272,
#  0.0117147006,
#  0.043441291900000005,
#  0.0332199968,
#  0.032659184200000003,
#  0.021372664700000002,
#  -0.07410785560000001,
#  0.044060036500000004,
#  0.0604799539,
#  0.0280885529,
#  -0.057681422700000005,
#  0.0473941043,
#  0.0115414327,
#  0.0056392695,
#  0.0064623295,
#  0.0006663578000000001,
#  0.0094200447,
#  0.0119224479,
#  0.0340757594,
#  0.0114753041,
#  0.0178158749,
#  0.0124857621,
#  -0.0232237224,
#  0.0143805379,
#  0.0160306264,
#  -0.0108767916,
#  0.0023660103,
#  0.007554288,
#  0.0139685543,
#  0.0024053361,
#  -0.024572527,
#  -0.0013426157000000001,
#  -0.0341077968,
#  -0.0051542236000000005,
#  0.0071750479,
#  0.0111817494,
#  0.016866792000000002,
#  0.0838655606,
#  -0.0076329415000000005,
#  -0.012903119400000001,
#  -0.014335759000000002,
#  0.060684971500000004,
#  -0.0343358815,
#  -0.006855003100000001,
#  -0.0994473547,
#  -0.0306727681,
#  0.017759433,
#  0.0110525768,
#  -0.059345118700000005,
#  0.0802998915,
#  0.0042923233,
#  -0.045192781800000005,
#  -0.0274547134,
#  -0.0520114265,
#  0.043851260100000004,
#  0.0199108664,
#  0.0170359295,
#  -0.028835658,
#  -0.0348747596,
#  0.0016817041,
#  0.0454863831,
#  -0.0060544792,
#  -0.0810129941,
#  2.664e-07,
#  -0.0107241934,
#  0.0276834704,
#  -0.0077656051000000005,
#  -0.0214271173,
#  -0.0091125723,
#  0.031406194000000005,
#  -0.1126212552,
#  -0.040891591500000005,
#  0.0186871439,
#  -0.0024081864000000002,
#  0.0175447799,
#  0.0359180123,
#  -0.0106656104,
#  0.0028980006,
#  -0.0294764005,
#  0.070209913,
#  -0.0844207108,
#  -0.0348115005,
#  -0.0203288998,
#  -0.009799345400000001,
#  0.0179717448,
#  0.0327263176,
#  -0.014474527000000001,
#  -0.0223738421,
#  -0.0209227558,
#  0.0254342388,
#  0.0111452918,
#  -0.0440078042,
#  0.07297176870000001,
#  -0.0156558361,
#  -0.0425089784,
#  -0.036707244800000004,
#  0.0303575601,
#  -0.010315531900000001,
#  0.0139902774,
#  -0.0017097821,
#  0.0656267703,
#  -0.0139781768,
#  0.034036018,
#  0.0560615994,
#  0.0351303704,
#  0.0107499417,
#  -0.0080555109,
#  -0.0060182051,
#  -0.0051681213,
#  0.057361632600000004,
#  -0.048936132300000004,
#  -0.0823068097,
#  -0.000429106,
#  0.031307891000000004,
#  0.0018298592000000002,
#  -0.000880752,
#  -0.030911589000000003,
#  -0.038470465700000005,
#  -0.0139830196,
#  -0.0278615821,
#  0.029871502900000003,
#  0.0073136776,
#  0.0122825745,
#  -0.012841479900000001,
#  0.0125974733,
#  -0.0121108321,
#  -0.013991142600000001,
#  0.0256858077,
#  0.053383119400000005,
#  0.0208906848,
#  -0.0191952419,
#  1.687614306e-34,
#  -0.0020207826000000003,
#  -0.0471234061,
#  -0.0113872997,
#  0.048032082600000005,
#  -0.0376567692,
#  -0.015335943500000001,
#  0.013268223,
#  0.0154688992,
#  -0.0266293064,
#  0.0274903737,
#  -0.02826651]

# %%
similarities = calculating_similarity_sklearn(query_embedding, text_embeddings, offset=1)

# %%
for similarity in similarities:
    term_name = eb_kg_df.loc[similarity["index"], "term_name"]
    print(f"term name: {term_name}, score: {similarity['score']}")
# Out:
# term name: JALEMUS, score: 0.9174686934632075
# term name: JALEMUS, score: 0.8772943130567594
# term name: JALEMUS, score: 0.8475532906894628
# term name: JALEMUS, score: 0.8148748575742857
# term name: MONODY, score: 0.7130271120678224
# term name: EPICEDIUM, score: 0.6476358814635169
# term name: ELEGI, score: 0.6218768102182376
# term name: MONODY, score: 0.6181812197105039
# term name: MONODY, score: 0.6161303561791671
# term name: EPICEDIUM, score: 0.6117035352533822
# term name: EPICEDIUM, score: 0.6080285260537095
# term name: EPICEDIUM, score: 0.6080284931314845
# term name: MONODY, score: 0.6065482571235987
# term name: MONODY, score: 0.588152880069543
# term name: GENETHLIA, score: 0.5872355263579042
# term name: GENETHLIA, score: 0.5872355176553301
# term name: ELEGIAC, score: 0.5835353365703346
# term name: ELEGIAC, score: 0.5835353365703346
# term name: MOURNING, score: 0.5776497152776886
# term name: MIMESIS, score: 0.5497770164934734

# %%
import math
def manual_cos_similarity(vector1, vector2):
    doc_product = sum( [vector1[i]*vector2[i] for i in range(len(vector1))] )
    len_vector1 = math.sqrt(sum([vector1[i]*vector1[i] for i in range(len(vector1))]))
    len_vector2 = math.sqrt(sum([vector2[i]*vector2[i] for i in range(len(vector2))]))
    return doc_product / (len_vector1*len_vector2)

# %%
manual_cos_result = manual_cos_similarity(query_embedding, text_embeddings[1])

# %%
manual_cos_result
# Out:
# 0.2287541277754158

# %% [markdown]
# using KNN search from Elasticsearch

# %%
from elasticsearch import Elasticsearch
client = Elasticsearch(
  "https://83a1253d6aac48278867d36eed60b642.us-central1.gcp.cloud.es.io:443",
  api_key="cmtBajU0MEJiRUoteDA3bmtubEE6bHpVYzFlSWNUSXFWcG8tbHFnOUFxQQ=="
)

eb_index = "eb_with_embeddings"
# Out:
# /Users/ly40/Documents/PhD/KnowledgeGraph/venv/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
def es_knn_search(query_embedding, top_n=20, offset=0):
    body = {
        "size": top_n,
        "from": offset,
        "_source": ["name"],
        "query": {
            "script_score": {
              "query" : {
                "match_all": {}
              },
              "script": {
                "source": "cosineSimilarity(params.queryVector, 'embedding') + 1.0",
                "params": {
                  "queryVector": query_embedding
                }
              }
            }
        }
    }
    response = client.search(index=eb_index, body=body)
    return response

# %%
response = es_knn_search(query_embedding, offset=1)

# %%
response
# Out:
# ObjectApiResponse({'took': 370, 'timed_out': False, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 10000, 'relation': 'gte'}, 'max_score': 2.0, 'hits': [{'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/9910796273804340_192693199_1475160240_0', '_score': 1.9174685, '_source': {'name': 'JALEMUS'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/997902543804341_149982181_1475160240_0', '_score': 1.8772943, '_source': {'name': 'JALEMUS'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/9910796233804340_191679019_1475160240_0', '_score': 1.8475533, '_source': {'name': 'JALEMUS'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/9910796253804340_192984257_1475160240_0', '_score': 1.8148748, '_source': {'name': 'JALEMUS'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/992277653804341_144133903_8470479892_0', '_score': 1.713027, '_source': {'name': 'MONODY'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/9910796253804340_192015836_7597619264_0', '_score': 1.6476359, '_source': {'name': 'EPICEDIUM'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/9922270543804340_191678898_8039672457_0', '_score': 1.6218768, '_source': {'name': 'ELEGI'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/997902543804341_190273372_8470479892_0', '_score': 1.6181812, '_source': {'name': 'MONODY'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/997902523804341_144850378_8470479892_0', '_score': 1.6161304, '_source': {'name': 'MONODY'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/9910796273804340_193696084_7597619264_0', '_score': 1.6117036, '_source': {'name': 'EPICEDIUM'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/9922270543804340_191678898_7597619264_0', '_score': 1.6080285, '_source': {'name': 'EPICEDIUM'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/992277653804341_144133902_7597619264_0', '_score': 1.6080284, '_source': {'name': 'EPICEDIUM'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/9910796273804340_193819044_8470479892_0', '_score': 1.6065483, '_source': {'name': 'MONODY'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/9910796233804340_191253838_8470479892_0', '_score': 1.5881529, '_source': {'name': 'MONODY'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/9922270543804340_193109108_8957741874_0', '_score': 1.5872356, '_source': {'name': 'GENETHLIA'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/9910796233804340_193109111_8957741874_1', '_score': 1.5872355, '_source': {'name': 'GENETHLIA'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/9910796253804340_192015836_1534310098_0', '_score': 1.5835354, '_source': {'name': 'ELEGIAC'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/997902523804341_144850375_1534310098_0', '_score': 1.5835354, '_source': {'name': 'ELEGIAC'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/9910796273804340_193819044_5027856848_1', '_score': 1.5776496, '_source': {'name': 'MOURNING'}}, {'_index': 'eb_with_embeddings', '_id': 'https://w3id.org/hto/ArticleTermRecord/997902543804341_190273372_5036004943_0', '_score': 1.549777, '_source': {'name': 'MIMESIS'}}]}})

# %% [markdown]
# Compare the result from knn search with cosine similarity from sklearn

# %%
import math
for index in range(len(similarities)):
    sklearn_similarity = similarities[index]
    sklearn_term_name = eb_kg_df.loc[sklearn_similarity["index"], "term_name"]
    sklearn_score = sklearn_similarity['score']
    sklearn_term_uri = eb_kg_df.loc[sklearn_similarity["index"], "term_uri"]

    es_knn_term_name = response["hits"]["hits"][index]["_source"]["name"]
    es_knn_term_uri = response["hits"]["hits"][index]["_id"]
    es_knn_score = response["hits"]["hits"][index]["_score"] - 1
    if sklearn_term_uri != es_knn_term_uri or sklearn_term_name != es_knn_term_name or not math.isclose(sklearn_score, es_knn_score, rel_tol=0.000001):
        print(f"result does not match! sklearn result: {sklearn_term_name}, {sklearn_score}, {sklearn_term_uri} | knn search result: {es_knn_term_name}, {es_knn_score}, {es_knn_term_uri}")
# Out:
# result does not match! sklearn result: ELEGIAC, 0.5835353365703346 | knn search result: ELEGIAC, 0.5835353999999999
# result does not match! sklearn result: ELEGIAC, 0.5835353365703346 | knn search result: ELEGIAC, 0.5835353999999999
